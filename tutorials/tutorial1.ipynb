# %% [markdown]
# <a href="https://colab.research.google.com/github/yassafbd/Introduction-to-Cloud-Computing/blob/main/tutorials/tutorial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
# Lec8.ipynb  Targil2.ipynb  tutorial1.ipynb  Untitled0.ipynb  Untitled1.ipynb

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 3, where = (y > 0), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()

# %%
#@title Default title text
# %%html
<style>
body {
  background-color: #f2bcca;
}
</style>
color = 'green' #@param ["red", "green", "blue"] print(color)
<svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
   <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
   <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0;" />
   <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0;" />
</svg>
# Out:
# <style>
# body {
#   background-color: #f2bcca;
# }
# </style>
# color = 'green' #@param ["red", "green", "blue"] print(color)
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0;" />
#    <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0;" />
# </svg>

# %%
import os
os.chdir("/content/drive/MyDrive/")

# %%
with open(' 1.txt', 'r') as file:
    contents = file.read()
    print(contents)
# Out:
# one
# two
# three

# %%
#@title 🎓 Student Management Form - Braude { display-mode: "form" }

# Mount Google Drive (Required to read/write the file)
from google.colab import drive
import os
drive.mount('/content/drive', force_remount=True)

# --- Form Fields ---
#@markdown ### Student Selection and Details:
student_selection = "Sarah Miller" #@param ["Alex Johnson", "Sarah Miller", "David Wilson", "Emily Davis"]
first_name = "Alex" #@param {type:"string"}
last_name = "Johnson" #@param {type:"string"}
email = "alex.j@braude.ac.il" #@param {type:"string"}
courses_list = "Data Structures, Algorithms" #@param {type:"string"}
cool_link = "https://github.com/alex-j" #@param {type:"string"}

#@markdown ---
#@markdown ### Data Update:
favorite_show = "shaked" #@param {type:"string"}

# Simple logic for saving (executed when clicking the 'Run' button)
file_path = '/content/drive/My Drive/students.txt'

if favorite_show:
    new_entry = f"{first_name}, {last_name}, {email}, [{courses_list}], {cool_link}, {favorite_show}\n"
    with open(file_path, 'a', encoding='utf-8') as f:
        f.write(new_entry)
    print(f"✅ Details for {first_name} have been successfully updated in the file!")
else:
    print("ℹ️ Please select a student, enter a 'Favorite Show', and click Play to update.")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_229/2374447338.py in <cell line: 0>()
#       4 from google.colab import drive
#       5 import os
# ----> 6 drive.mount('/content/drive', force_remount=True)
#       7
#       8 # --- Form Fields ---
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
# ...
